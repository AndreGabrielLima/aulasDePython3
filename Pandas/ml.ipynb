# %%
import pandas as pd
from sklearn import linear_model

# %%
dataframe = pd.DataFrame()
dataframe['x'] = [5.1, 5.5, 5.9, 6.5, 6.8, 7.6, 8.3, 8.5, 9.1, 9.5]
dataframe['y'] = [2.0, 2.9, 4.0, 5.9, 6.0, 6.9, 8.0, 9.0, 9.9, 11.0]
x_values = dataframe[['x']]
y_values = dataframe[['y']]

model = linear_model.LinearRegression()
model.fit(x_values, y_values)

print('Utilizando biblioteca scikit-learn no python')
print('y = ax + b')
print('a = %2f = a inclinação da linha de tendência.' % model.coef_[0][0])
print('b = %2f = o ponto onde a linha de tendência atinge o eixo y.' % model.intercept_[0])
# Out:
# Utilizando biblioteca scikit-learn no python
# y = ax + b
# a = 1.915955 = a inclinação da linha de tendência.
# b = -7.388150 = o ponto onde a linha de tendência atinge o eixo y.

# %%
dataframe.plot()
x = float(input('horas: '))
y = 1.92*x - 7.39
print(y)
# Out:
# horas: 8
# 7.97
