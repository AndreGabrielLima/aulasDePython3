# %%
import pandas as pd

# %%
url = 'http://pt.wikipedia.org/wiki/Lista_de_guerras_por_n%C3%BAmero_de_mortos'

# %%
tables = pd.read_html(url)

# %%
tables[1]
# Out:
#                                   Guerra  \
# 0                 Segunda Guerra Mundial
# 1          Conquistas e invasões mongóis
# 2                 Guerra dos Três reinos
# 3           Segunda Guerra Sino-Japonesa
# 4        Conquista Qing da dinastia Ming
# 5                       Rebelião Taiping
# 6  Primeira Guerra Mundial/Grande Guerra
# 7                 Rebelião de An Lushuan
# 8                         Revolta Dungan
# 9                 Conquistas de Tamerlão
#
#                                               Mortes        Ano  \
# 0                              70 000 000–85 000 000  1939–1945
# 1                              30 000 000–40 000 000  1206–1368
# 2                              36 000 000–40 000 000    184–280
# 3                              20 000 000–25 000 000  1937–1945
# 4                                         25 000 000  1616–1662
# 5                              20 000 000–70 000 000  1850–1864
# ...

# %%
tables[2]
# Out:
#                                              Guerra                 Mortes  \
# 0                              Guerra Civil Chinesa              8 000 000
# 1                                Guerra Civil Russa    5 000 000–9 000 000
# 2                              Guerras Napoleônicas   3 500 000– 6 000 000
# 3                            Guerra dos Trinta Anos  3 000 000– 11 500 000
# 4   Segunda Guerra do Congo/Guerra Mundial Africana   2 500 000– 5 400 000
# 5                      Guerras Religiosas na França   2 000 000– 4 000 000
# 6                               Guerra Goguryeo–Sui   2 000 000 pelo menos
# 7                          Conquistas de Shaka Zulu              2 000 000
# 8                                  Guerra da Coreia              1 200 000
# 9                                Cerco de Jerusalém              1 100 000
# 10                               Revolução Mexicana   1 000 000– 2 000 000
# ...
